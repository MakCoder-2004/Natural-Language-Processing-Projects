# %% [markdown]
# # News Articles Summarizer

# %% [markdown]
# ## Libraries

# %%
from newspaper import Article

# %% [markdown]
# ## Summerize Article

# %%
url = "https://jamesclear.com/five-step-creative-process"
article = Article(url)
article.download()
article.parse()
article.nlp()

# %%
print(f"Title: {article.title}")
print(f"Authors: {article.authors}")
print(f"Publish Date: {article.publish_date}")
print(f"Summary: {article.summary}")
# Out:
# Title: For a More Creative Brain Follow These 5 Steps
# Authors: ['James Clear']
# Publish Date: 2016-07-25 18:35:20+00:00
# Summary: Nearly all great ideas follow a similar creative process and this article explains how this process works.
# Understanding this is important because creative thinking is one of the most useful skills you can possess.
# His story of creativity and innovation, which I will share now, is a useful case study for understanding the 5 key steps of the creative process.
# The Idea in PracticeThe creative process used by Frederic Eugene Ives offers a perfect example of these five steps in action.
# (On a personal note, I often find creative ideas hit me just as I am lying down for sleep.

# %% [markdown]
# ---
